# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':"a-price-whole"}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'class':"a-price-whole"}).string.strip()

        except:
            price = "400"

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_324\4254666078.py:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   amazon_df['title'].replace('', np.nan, inplace=True)

# %%
amazon_df
# Out:
#                                                 title price  \
# 1   PlayStation®4 Console – Call of Duty® Modern W...   400
# 2   DualShock 4 Wireless Controller for PlayStatio...   400
# 3   PlayStation 4 Slim 1TB Limited Edition Console...   400
# 4   PS4 Controller Charger Dock Station, PS4 Remot...   400
# 5   PlayStation 4 Jet Black (CUH-1200AB01) [Japan ...   400
# 6   PlayStation 4 Slim 500GB Console [Discontinued...   400
# 7                      PlayStation 4 Slim 1TB Console   400
# 8              Sony Playstation PS4 1TB Black Console   400
# 9   Playstation Sony 4, 500GB Slim System [CUH-221...   400
# 10                      PlayStation 4 Pro 1TB Console   400
# 11                                      PlayStation 4   400
# 12  Sony PlayStation 4 Pro 1TB Console - Black (PS...   400
# 13  Flagship Play Station 4 1TB HDD Only on Playst...   400
# 14               PlayStation®5 Digital Edition (slim)   400
# 15  PlayStation 4 Slim 1TB Console - Marvel's Spid...   400
# 16  PlayStation 4 500GB Console - Call of Duty Bla...   400
# 17     Call of Duty Black Ops 4 - PlayStation 4 (PS4)   400
# 18  TERIOS Wireless Controller Compatible with PS4...   400
# 19  GamingBoy 2 Pack Wireless Controller for PS4, ...   400
# 20  CHEREEKI Wireless Controller for PS4 with 2 Ma...   400
# 21  PS4 Controller 2 Pack Wireless for PlayStation...   400
# 22  DEEBOX Gaming Headset for PC, PS5, PS4, Xbox, ...   400
# 23  BRENDEZ Replacement Set of Cables,- HDMI Cable...   400
# 24  eeidc PS4 Controller 2 Pack Wireless Remote Co...   400
# 25  Turtle Beach Stealth 600 Wireless Multiplatfor...   400
# 26  Turtle Beach Stealth 700 Gen 3 Wireless Multip...   400
# 27  PHOINIKAS Gaming Headset for PS4, Xbox One, PC...   400
# 28  Gaming Headset for PS5 PS4 PC, Wired Headsets ...   400
# 29  Gaming Headset with Microphone, Gaming Headpho...   400
#
#                 rating          reviews                      availability
# 1   4.5 out of 5 stars      157 ratings                     Not Available
# 2   4.6 out of 5 stars  169,830 ratings                     Not Available
# 3   5.0 out of 5 stars        2 ratings                     Not Available
# 4   4.7 out of 5 stars    3,727 ratings                     Not Available
# 5   3.8 out of 5 stars      867 ratings  Usually ships within 6 to 7 days
# 6   4.0 out of 5 stars    3,082 ratings                     Not Available
# 7   4.6 out of 5 stars   15,807 ratings                     Not Available
# 8   4.6 out of 5 stars    1,631 ratings                     Not Available
# 9   4.4 out of 5 stars      394 ratings                     Not Available
# 10  4.6 out of 5 stars   12,777 ratings                     Not Available
# 11  4.6 out of 5 stars   13,677 ratings                     Not Available
# 12  4.4 out of 5 stars    4,134 ratings                     Not Available
# 13  4.5 out of 5 stars      214 ratings                     Not Available
# 14  4.7 out of 5 stars    6,278 ratings                     Not Available
# 15  4.6 out of 5 stars    2,825 ratings                     Not Available
# 16  4.6 out of 5 stars    2,012 ratings                     Not Available
# 17  4.3 out of 5 stars      546 ratings                          In Stock
# 18  4.0 out of 5 stars    7,869 ratings                     Not Available
# 19  4.5 out of 5 stars      147 ratings                     Not Available
# 20  4.1 out of 5 stars      146 ratings                     Not Available
# 21  4.5 out of 5 stars       30 ratings                     Not Available
# 22  4.3 out of 5 stars    3,122 ratings
# 23  4.7 out of 5 stars       58 ratings                     Not Available
# 24  4.0 out of 5 stars      157 ratings                     Not Available
# 25  4.2 out of 5 stars    2,202 ratings                          In Stock
# 26  4.3 out of 5 stars      339 ratings                          In Stock
# 27  4.2 out of 5 stars   13,491 ratings                     Not Available
# 28  4.1 out of 5 stars      420 ratings                     Not Available
# 29  4.3 out of 5 stars    1,699 ratings                     Not Available
